# %% [markdown]
# #### 本賽題提供用戶在2016年1月1日至2016年5月31日之間真實線下消費行為，預測用戶在2016年6月領取優惠券後15天以內的使用情況。

# %% [markdown]
# #### 本賽題目標是預測投放的優惠券是否在規定時間內核銷。針對此任務及一些相關背景知識，以該用戶使用於某日取得之優惠券核銷預測 AUC（ROC 曲線下面積）作為評價標準。即對將 User_id - Date_received - Coupon_id 為一組計算核銷預測的AUC值，若某使用者於同一日取得多張相同優惠券，則任一張核銷皆為有效核銷。

# %%
import os
import numpy as np
import pandas as pd
from datetime import date

from sklearn.model_selection import KFold, train_test_split, StratifiedKFold, cross_val_score, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import log_loss, roc_auc_score, auc, roc_curve
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder

data_path = "../../../mlkaggle/"

# %%
df = pd.read_csv(os.path.join(data_path,'train_offline.csv'))
dftest = pd.read_csv(os.path.join(data_path,'test_offline.csv'))
dftest = dftest[~dftest.Coupon_id.isna()]
dftest.reset_index(drop=True, inplace=True)
print(df.shape)
print(dftest.shape)
df.head()
# Out:
# (1160742, 7)
# (306313, 6)
#    User_id  Merchant_id  Coupon_id Discount_rate  Distance  Date_received  \
# 0  1439408         2632        NaN           NaN       0.0            NaN
# 1  1439408         2632     8591.0          20:1       0.0     20160217.0
# 2  1439408         2632     1078.0          20:1       0.0     20160319.0
# 3  1832624         3381     7610.0        200:20       0.0     20160429.0
# 4  2029232         3381    11951.0        200:20       1.0     20160129.0
#
#          Date
# 0  20160217.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# 因為需要把類別型與數值型特徵都加入, 故使用最簡版的特徵工程
LEncoder = LabelEncoder()
MMEncoder = MinMaxScaler()
for c in df.columns:
    df[c] = df[c].fillna(-1)
    if df[c].dtype == 'object':
        df[c] = LEncoder.fit_transform(list(df[c].values))
    df[c] = MMEncoder.fit_transform(df[c].values.reshape(-1, 1))
df.head()
# Out:
#     User_id  Merchant_id  Coupon_id  Discount_rate  Distance  Date_received  \
# 0  0.195544     0.297120   0.000000       0.000000  0.090909       0.000000
# 1  0.195544     0.297120   0.611704       0.644444  0.090909       0.999989
# 2  0.195544     0.297120   0.076819       0.644444  0.090909       0.999994
# 3  0.248963     0.381705   0.541862       0.555556  0.090909       1.000000
# 4  0.275672     0.381705   0.850918       0.555556  0.181818       0.999985
#
#       Date
# 0  0.99998
# 1  0.00000
# 2  0.00000
# 3  0.00000
# 4  0.00000
